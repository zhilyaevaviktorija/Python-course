# %% [markdown]
# <a href="https://colab.research.google.com/github/zhilyaevaviktorija/Python-course/blob/main/Homework_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1: выгрузка файлов

# %% [markdown]
# 1. Зайдите в репозиторий датасетов для обучения диалоговых систем
# 2. Найдите все файлы с расширением *.txt (их всего 5 в репозитории)
# 3. Выгрузите каждый файл с помощью утилиты `wget`
# - Для этого откройте датасет в браузере, например, https://github.com/Phylliida/Dialogue-Datasets/blob/master/TwitterLowerAsciiCorpus.txt
# - Затем найдите кнопку `raw`, которая откроет вам файл "как есть" (как в блокноте!)
# - Скопируйте ссылку на файл (она выглядит так: https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt)
# - Воспользуйтесь `wget`
# ---
# Как использовать `wget`:
# ---

# %%
# dataset 1
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt -O twitter.txt
# Out:
# --2025-12-05 16:10:23--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 593707 (580K) [text/plain]
# Saving to: ‘twitter.txt’
#
# twitter.txt         100%[===================>] 579.79K  --.-KB/s    in 0.04s
#
# 2025-12-05 16:10:23 (12.9 MB/s) - ‘twitter.txt’ saved [593707/593707]

# %% [markdown]
# Здесь:
# - ! указывает на то, что это консольная утилита, а не код на python
# - после wget идет полный адрес ссылки для скачивания файла
# - после параметра `-O` указываем название файла, под которым мы хотим скачать файл

# %%
# dataset 2
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterConvCorpus.txt -O twitter_conv.txt
# Out:
# --2025-12-05 17:12:27--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterConvCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 612338 (598K) [text/plain]
# Saving to: ‘twitter_conv.txt’
#
# twitter_conv.txt    100%[===================>] 597.99K  --.-KB/s    in 0.04s
#
# 2025-12-05 17:12:27 (13.7 MB/s) - ‘twitter_conv.txt’ saved [612338/612338]

# %%
# dataset 3
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/MovieCorpus.txt -O movie.txt
# Out:
# --2025-12-05 17:12:35--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/MovieCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16976724 (16M) [text/plain]
# Saving to: ‘movie.txt’
#
# movie.txt           100%[===================>]  16.19M  --.-KB/s    in 0.1s
#
# 2025-12-05 17:12:36 (148 MB/s) - ‘movie.txt’ saved [16976724/16976724]

# %%
# dataset 4
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCSplitWordsCorpus.txt -O bnc_split.txt
# Out:
# --2025-12-05 17:12:38--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCSplitWordsCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19173003 (18M) [text/plain]
# Saving to: ‘bnc_split.txt’
#
# bnc_split.txt       100%[===================>]  18.28M   105MB/s    in 0.2s
#
# 2025-12-05 17:12:38 (105 MB/s) - ‘bnc_split.txt’ saved [19173003/19173003]

# %%
# dataset 5
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCCorpus.txt -O bnc.txt
# Out:
# --2025-12-05 17:12:40--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19081694 (18M) [text/plain]
# Saving to: ‘bnc.txt’
#
# bnc.txt             100%[===================>]  18.20M  --.-KB/s    in 0.1s
#
# 2025-12-05 17:12:41 (138 MB/s) - ‘bnc.txt’ saved [19081694/19081694]

# %% [markdown]
# ## Задание 2: открываем файлы

# %% [markdown]
# Изучите туториал по работе с файлами, который вы получили в чате. Каждый файл нужно теперь открыть, а его содержание - записать в переменную *любым удобным вам способом*
#
# Пример:

# %%
# dataset 1
# Открываем файл с указанием кодировки
file = open('twitter.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 593707 символов
# "what's up dadyo when did you get back on twitter? haha\nlike 2 weeks ago and it's going as terribly a"

# %%
# dataset 2
# Открываем файл с указанием кодировки
file = open('twitter_conv.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 598556 символов
# "what's up dadyo when did you get back on Twitter? Haha\nlike 2 weeks ago and it's going as terribly a"

# %%
# dataset 3
# Открываем файл с указанием кодировки
file = open('movie.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 16976724 символов
# "Colonel Durnford... William Vereker. I hear you 've been seeking Officers?\nGood ones, yes, Mr Vereke"

# %%
# dataset 4
# Открываем файл с указанием кодировки
file = open('bnc_split.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 19173003 символов
# 'You enjoyed yourself in America\nEh\ndid you\nOh I covered a nice trip yes\nOh very good\nsaw Mary and An'

# %%
# dataset 5
# Открываем файл с указанием кодировки
file = open('bnc.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 19081694 символов
# 'You enjoyed yourself in America\nEh\ndid you\nOh I covered a nice tripyes\nOh very good\nsaw Mary and And'

# %% [markdown]
# ## Задание 3: первичный анализ

# %% [markdown]
# Выведем статистику для каждого файла по образцу:

# %%
# dataset 1
# 1. Разбиваем содержание файла на строки
with open('twitter.txt', 'r', encoding='utf-8') as file:
    lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

total_lines = len(lines)

for line in lines:
    # Убираем символ новой строки для корректного подсчета
    line_content = line.rstrip('\n')
    total_chars += len(line_content)

    # Проверяем, не пустая ли строка
    if line_content.strip():  # строка содержит не только пробелы
        non_empty_lines += 1
        total_words += len(line_content.split())

# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
min_line_length = 0   # максимальная длина строки

min_line_length = float('inf')

for line in lines:
    line_content = line.rstrip('\n')
    dataset_length = len(line_content)

# Пропускаем полностью пустые строки при поиске минимума
    if line_content.strip():
        if dataset_length > max_line_length:
            max_line_length = dataset_length

        if dataset_length < min_line_length:
            min_line_length = dataset_length

# Если не нашли ни одной непустой строки, устанавливаем минимум в 0
if min_line_length == float('inf'):
    min_line_length = 0

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 16556
# Непустых строк: 1
# Всего слов: 10
# Всего символов: 577151
# Макс. длина строки: 146
# Мин. длина строки: 1

# %%
# dataset 2
# 1. Разбиваем содержание файла на строки
with open('twitter_conv.txt', 'r', encoding='utf-8') as file:
    lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

total_lines = len(lines)

for line in lines:
    # Убираем символ новой строки для корректного подсчета
    line_content = line.rstrip('\n')
    total_chars += len(line_content)

    # Проверяем, не пустая ли строка
    if line_content.strip():  # строка содержит не только пробелы
        non_empty_lines += 1
        total_words += len(line_content.split())

# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
min_line_length = 0   # максимальная длина строки

min_line_length = float('inf')

for line in lines:
    line_content = line.rstrip('\n')
    dataset_length = len(line_content)

# Пропускаем полностью пустые строки при поиске минимума
    if line_content.strip():
        if dataset_length > max_line_length:
            max_line_length = dataset_length

        if dataset_length < min_line_length:
            min_line_length = dataset_length

# Если не нашли ни одной непустой строки, устанавливаем минимум в 0
if min_line_length == float('inf'):
    min_line_length = 0

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 16556
# Непустых строк: 1
# Всего слов: 10
# Всего символов: 582000
# Макс. длина строки: 146
# Мин. длина строки: 1

# %%
# dataset 3
# 1. Разбиваем содержание файла на строки
with open('movie.txt', 'r', encoding='utf-8') as file:
    lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

total_lines = len(lines)

for line in lines:
    # Убираем символ новой строки для корректного подсчета
    line_content = line.rstrip('\n')
    total_chars += len(line_content)

    # Проверяем, не пустая ли строка
    if line_content.strip():  # строка содержит не только пробелы
        non_empty_lines += 1
        total_words += len(line_content.split())

# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
min_line_length = 0   # максимальная длина строки

min_line_length = float('inf')

for line in lines:
    line_content = line.rstrip('\n')
    dataset_length = len(line_content)

# Пропускаем полностью пустые строки при поиске минимума
    if line_content.strip():
        if dataset_length > max_line_length:
            max_line_length = dataset_length

        if dataset_length < min_line_length:
            min_line_length = dataset_length

# Если не нашли ни одной непустой строки, устанавливаем минимум в 0
if min_line_length == float('inf'):
    min_line_length = 0

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 304713
# Непустых строк: 1
# Всего слов: 3
# Всего символов: 16672011
# Макс. длина строки: 3039
# Мин. длина строки: 1

# %%
# dataset 4
# 1. Разбиваем содержание файла на строки
with open('bnc_split.txt', 'r', encoding='utf-8') as file:
    lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

total_lines = len(lines)

for line in lines:
    # Убираем символ новой строки для корректного подсчета
    line_content = line.rstrip('\n')
    total_chars += len(line_content)

    # Проверяем, не пустая ли строка
    if line_content.strip():  # строка содержит не только пробелы
        non_empty_lines += 1
        total_words += len(line_content.split())

# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
min_line_length = 0   # максимальная длина строки

min_line_length = float('inf')

for line in lines:
    line_content = line.rstrip('\n')
    dataset_length = len(line_content)

# Пропускаем полностью пустые строки при поиске минимума
    if line_content.strip():
        if dataset_length > max_line_length:
            max_line_length = dataset_length

        if dataset_length < min_line_length:
            min_line_length = dataset_length

# Если не нашли ни одной непустой строки, устанавливаем минимум в 0
if min_line_length == float('inf'):
    min_line_length = 0

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 611014
# Непустых строк: 1
# Всего слов: 6
# Всего символов: 18561989
# Макс. длина строки: 2773
# Мин. длина строки: 1

# %%
# dataset 5
# 1. Разбиваем содержание файла на строки
with open('bnc.txt', 'r', encoding='utf-8') as file:
    lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

total_lines = len(lines)

for line in lines:
    # Убираем символ новой строки для корректного подсчета
    line_content = line.rstrip('\n')
    total_chars += len(line_content)

    # Проверяем, не пустая ли строка
    if line_content.strip():  # строка содержит не только пробелы
        non_empty_lines += 1
        total_words += len(line_content.split())

# 3. Анализ длин строк
max_line_length = 0   # минимальная длина строки
min_line_length = 0   # максимальная длина строки

min_line_length = float('inf')

for line in lines:
    line_content = line.rstrip('\n')
    dataset_length = len(line_content)

# Пропускаем полностью пустые строки при поиске минимума
    if line_content.strip():
        if dataset_length > max_line_length:
            max_line_length = dataset_length

        if dataset_length < min_line_length:
            min_line_length = dataset_length

# Если не нашли ни одной непустой строки, устанавливаем минимум в 0
if min_line_length == float('inf'):
    min_line_length = 0

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 611014
# Непустых строк: 606486
# Всего слов: 3719853
# Всего символов: 18470680
# Макс. длина строки: 2702
# Мин. длина строки: 1

# %% [markdown]
# ## Задание 4: чистка текста

# %%
import re

cleaned_lines = [] # чистим текст построчно (сохраняем каждую очищенную строку в список)
all_cleaned_words = [] # также сохраняем все слова после очистки в список

# Ваш код здесь: реализуйте очистку с помощью цикла for и RegEx
for line in lines:
    # 1. Используйте strip для удаления лишних пробелов из строки
    line_clean = line.strip()

    # 2. Очищаем строку: оставляем только буквы, цифры и пробелы
    # Убираем все, кроме букв, цифр и пробелов
    line_clean = re.sub(r'[^\w\s]', '', line_clean)

    # 3. Убираем лишние пробелы
    line_clean = re.sub(r'\s+', ' ', line_clean)

    # 4. Приводим к нижнему регистру
    line_clean = line_clean.lower()

    # Добавляем очищенную строку в список (если она не пустая)
    if line_clean:
        cleaned_lines.append(line_clean)

        # 5. Собираем все слова после очистки в единый список
        words = line_clean.split()

        # - не фиксируем слова короче 1 символа
        for word in words:
            if len(word) > 1:  # только слова длиннее 1 символа
                all_cleaned_words.append(word)



# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words)}")
# Out:
# Пример очищенной строки: you enjoyed yourself in america...
# Всего очищенных слов: 3524835

# %% [markdown]
# ## Задание 5: статистика

# %% [markdown]
# Часть 1: получаем статистику распределений длин слов

# %%
# Статистика по очищенным данным
total_words_after = len(all_cleaned_words)
total_chars_after = 0
word_lengths = []

# Ваш код здесь: создайте список длин слов word_lengths
#                и посчитайте общее количество символов total_chars
for word in all_cleaned_words:
    word_len = len(word)
    word_lengths.append(word_len)
    total_chars_after += word_len

# Анализ длин слов: допишите код для подсчета количества слов разной длины
word_length_count = {}
# Ваш код здесь: для каждого значения длины в списке word_lengths
#                если длина уже зафиксирована в word_length_count, то выполняем >
#        word_length_count[length] += 1
#                иначе: выполняем >
#        word_length_count[length] = 1

for length in word_lengths:
    if length in word_length_count:
        word_length_count[length] += 1
    else:
        word_length_count[length] = 1

# Ожидаемый результат:
print(f"Слов после очистки: {total_words_after}")
print(f"Символов после очистки: {total_chars_after}")
print("Распределение длин слов:")
for length in sorted(word_length_count.keys()):
    print(f"  {length} букв: {word_length_count[length]} слов")
# Out:
# Слов после очистки: 3524835
# Символов после очистки: 14643163
# Распределение длин слов:
#   2 букв: 666389 слов
#   3 букв: 880968 слов
#   4 букв: 880766 слов
#   5 букв: 425302 слов
#   6 букв: 255069 слов
#   7 букв: 175610 слов
#   8 букв: 102856 слов
#   9 букв: 60865 слов
#   10 букв: 34706 слов
#   11 букв: 16675 слов
#   12 букв: 10611 слов
#   13 букв: 5627 слов
#   14 букв: 3330 слов
#   15 букв: 1970 слов
#   16 букв: 1292 слов
#   17 букв: 667 слов
#   18 букв: 559 слов
#   19 букв: 331 слов
#   20 букв: 262 слов
#   21 букв: 173 слов
#   22 букв: 162 слов
#   23 букв: 94 слов
#   24 букв: 98 слов
#   25 букв: 62 слов
#   26 букв: 45 слов
#   27 букв: 56 слов
#   28 букв: 32 слов
#   29 букв: 28 слов
#   30 букв: 31 слов
#   31 букв: 12 слов
#   32 букв: 34 слов
#   33 букв: 16 слов
#   34 букв: 14 слов
#   35 букв: 18 слов
#   36 букв: 17 слов
#   37 букв: 2 слов
#   38 букв: 3 слов
#   39 букв: 18 слов
#   40 букв: 3 слов
#   41 букв: 2 слов
#   42 букв: 6 слов
#   43 букв: 2 слов
#   44 букв: 3 слов
#   45 букв: 7 слов
#   47 букв: 4 слов
#   48 букв: 4 слов
#   49 букв: 1 слов
#   51 букв: 2 слов
#   53 букв: 1 слов
#   54 букв: 1 слов
#   56 букв: 2 слов
#   57 букв: 1 слов
#   58 букв: 1 слов
#   59 букв: 5 слов
#   60 букв: 7 слов
#   63 букв: 1 слов
#   65 букв: 4 слов
#   66 букв: 1 слов
#   87 букв: 1 слов
#   90 букв: 1 слов
#   104 букв: 1 слов
#   105 букв: 2 слов
#   112 букв: 1 слов
#   114 букв: 1 слов

# %% [markdown]
# Часть 2: частотность слов

# %%
# Считаем частотность слов (по аналогии с подсчетом word_length_count)
word_frequency = {}
# Ваш код здесь:
# проходим по all_cleaned_words
# если слово зафиксировано в word_frequency, то
#        word_frequency[word] += 1
# иначе
#        word_frequency[word] = 1

for word in all_cleaned_words:
    if word in word_frequency:
        word_frequency[word] += 1
    else:
        word_frequency[word] = 1

# Находим топ-10 самых частых слов
# Начинаем с формирования кортежей вида (частотность слова, лексема)
word_count_pairs = []
for word, count in word_frequency.items():
    word_count_pairs.append((count, word))

# Сортируем вручную через вложенные циклы
n = len(word_count_pairs)
for i in range(n):
    for j in range(i + 1, n):
        if word_count_pairs[j][0] > word_count_pairs[i][0]:
            # Меняем местами
            temp = word_count_pairs[i]
            word_count_pairs[i] = word_count_pairs[j]
            word_count_pairs[j] = temp

print("Топ-10 самых частых слов:")
for i in range(min(10, len(word_count_pairs))):
    count, word = word_count_pairs[i]
    print(f"  {i+1}. '{word}': {count} раз")

# Анализ уникальных слов
# Ваш код здесь: создайте множество unique_words
unique_words = set(all_cleaned_words)

print(f"\nВсего уникальных слов: {len(unique_words)}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1768962086.py in <cell line: 0>()
#      24 for i in range(n):
#      25     for j in range(i + 1, n):
# ---> 26         if word_count_pairs[j][0] > word_count_pairs[i][0]:
#      27             # Меняем местами
#      28             temp = word_count_pairs[i]
#
# KeyboardInterrupt:
